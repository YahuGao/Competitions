# %% [markdown]
# （1）使用bert后五层输出的平均值作为模型的输入
#     maxlen = 250
#     epochs = 20
#     batch_size = 16
#     bert_layers = 12
#     learing_rate = 1e-4
#     在第六轮达到最佳状态：valid:  f1: 0.71534, precision: 0.64916, recall: 0.79654, best f1: 0.71534
#     本地验证结果为：(0.6574556830031372, 0.6270512182993628, 0.6909589041095975)
#     效果不好，不进行线上提交
#  (2) 在(1)的基础上使用动态学习率
#      model_name = './weights/best_model_epoch_10_dynamic-lr.weights'
#      其它设置不变
#      本地验证结果为：(0.6008968609865585, 0.6365307998774246, 0.5690410958904227)
#      效果不好，不进行线上提交
#  (3) 在(2)的基础上， 将后五层的平均值， 改为对bert最后一层进行微调
#      model_name = './weights/best_model_epoch_20_finetune.weights'
#      其它设置不变
#      训练过程中， f1是逐步上升的，下降后也能逐步升起来 （1）和（2）是很快出现最高f1， 然后在较差的结果中上下抖动
#      本地验证结果为：(0.6723833543505757, 0.622897196261691, 0.730410958904117)
#      训练过程中，虽然设置了动态学习率， 但学习率从未改变过，降低模型的拟合耐心，再试一次
# ######## 总结：对最后一层进行微调， 显著改善了模型的本地验证效果 ########
#      本地验证结果为：(0.683803942461383, 0.6653706583722223, 0.7032876712328848)
#      线上测试结果为：score:0.7277，f1:0.7277 p:0.6979 r:0.7601
#  (4) 在（3）的基础上， 对最后两层进行微调
#      model_name = './weights/best_model_epoch_20_finetune_2layers.weights'
#      每轮大概需要1分钟
#      本地验证结果为：(0.6996833438885446, 0.6506478209658504, 0.7567123287671299)
# ######## 总结：对最后两层进行微调，模型的本地验证效果并不能说是得到改善 ########
#     设置在f1得到改善时， 学习率扩大，再次进行训练

# %%
model_name = './weights/best_model_epoch_20_finetune_2layers.weights'
maxlen = 250
epochs = 20
batch_size = 16
bert_layers = 12
learing_rate = 1e-4  # bert_layers越小，学习率应该要越大
crf_lr_multiplier = 1000  # 必要时扩大CRF层的学习率

# bert配置
config_path = '/data/bert/bert_config.json'
checkpoint_path = '/data/bert/bert_model.ckpt'
dict_path = '/data/bert/vocab.txt'

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import tensorflow as tf
tf.__version__

# %%
import keras
keras.__version__

# %%
import sys
# sys.path.insert(0,'/notebook/.custom/TF2.1.0_JUPYTER2_gpu/pylib/Python3')
import bert4keras
bert4keras.__version__

# %%
#! -*- coding: utf-8 -*-
import numpy as np
from bert4keras.backend import keras, K
from bert4keras.models import build_transformer_model
from bert4keras.tokenizers import Tokenizer
from bert4keras.optimizers import Adam
from bert4keras.snippets import sequence_padding, DataGenerator
from bert4keras.snippets import open, ViterbiDecoder, to_array
from bert4keras.layers import ConditionalRandomField
from keras.layers import Dense
from keras.models import Model
from tqdm import tqdm

# %%
def load_data(filename):
    D = []
    with open(filename, encoding='utf-8') as f:
        f = f.read()
        for l in f.split('\n\n'):
            if not l:
                continue
            d, last_flag = [], ''
            for c in l.split('\n'):
                try:
                    char, this_flag = c.split(' ')
                except:
                    print(c)
                    continue
                if this_flag == 'O' and last_flag == 'O':
                    d[-1][0] += char
                elif this_flag == 'O' and last_flag != 'O':
                    d.append([char, 'O'])
                elif this_flag[:1] == 'B':
                    d.append([char, this_flag[2:]])
                else:
                    d[-1][0] += char
                last_flag = this_flag
            D.append(d)
    return D

# 标注数据
train_data = load_data('./round1_train/data/train.txt')
valid_data = load_data('./round1_train/data/val.txt')

# %%
# 建立分词器
# Tokenizer
tokenizer = Tokenizer(dict_path, do_lower_case=True)

# 类别映射

labels = ['SYMPTOM',
 'DRUG_EFFICACY',
 'PERSON_GROUP',
 'SYNDROME',
 'DRUG_TASTE',
 'DISEASE',
 'DRUG_DOSAGE',
 'DRUG_INGREDIENT',
 'FOOD_GROUP',
 'DISEASE_GROUP',
 'DRUG',
 'FOOD',
 'DRUG_GROUP']

id2label = dict(enumerate(labels))
label2id = {j: i for i, j in id2label.items()}
num_labels = len(labels) * 2 + 1


class data_generator(DataGenerator):
    """数据生成器
    """
    def __iter__(self, random=False):
        batch_token_ids, batch_segment_ids, batch_labels = [], [], []
        for is_end, item in self.sample(random):
            token_ids, labels = [tokenizer._token_start_id], [0]
            for w, l in item:
                w_token_ids = tokenizer.encode(w)[0][1:-1]
                if len(token_ids) + len(w_token_ids) < maxlen:
                    token_ids += w_token_ids
                    if l == 'O':
                        labels += [0] * len(w_token_ids)
                    else:
                        B = label2id[l] * 2 + 1
                        I = label2id[l] * 2 + 2
                        labels += ([B] + [I] * (len(w_token_ids) - 1))
                else:
                    break
            token_ids += [tokenizer._token_end_id]
            labels += [0]
            segment_ids = [0] * len(token_ids)
            batch_token_ids.append(token_ids)
            batch_segment_ids.append(segment_ids)
            batch_labels.append(labels)
            if len(batch_token_ids) == self.batch_size or is_end:
                batch_token_ids = sequence_padding(batch_token_ids)
                batch_segment_ids = sequence_padding(batch_segment_ids)
                batch_labels = sequence_padding(batch_labels)
                yield [batch_token_ids, batch_segment_ids], batch_labels
                batch_token_ids, batch_segment_ids, batch_labels = [], [], []

# %%
#  指定使用GPU
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # 选用GPU序号
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %% [markdown]
# 获取base bert后五层的输出， 求算术平均
# output_layer1 = 'Transformer-%s-FeedForward-Norm' % (bert_layers - 1)
# output_layer1 = model.get_layer(output_layer1).output
# output_layer2 = 'Transformer-%s-FeedForward-Norm' % (bert_layers - 2)
# output_layer2 = model.get_layer(output_layer2).output
# output_layer3 = 'Transformer-%s-FeedForward-Norm' % (bert_layers - 3)
# output_layer3 = model.get_layer(output_layer3).output
# output_layer4 = 'Transformer-%s-FeedForward-Norm' % (bert_layers - 4)
# output_layer4 = model.get_layer(output_layer4).output
# output_layer5 = 'Transformer-%s-FeedForward-Norm' % (bert_layers - 5)
# output_layer5 = model.get_layer(output_layer5).output
#
# output = keras.layers.add([output_layer1, output_layer2, output_layer3, output_layer4, output_layer5])

# %%
pretrained_bert = build_transformer_model(
    config_path,
    checkpoint_path,
)

pretrained_bert.trainable = True
set_trainable = False
for layer in pretrained_bert.layers:
    if layer.name.startswith('Transformer-1'):
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

output_layer1 = 'Transformer-%s-FeedForward-Norm' % (bert_layers - 1)
# 把bert最后一层的输出送入 模型
output = pretrained_bert.get_layer(output_layer1).output
output = Dense(num_labels)(output) # 27分类

CRF = ConditionalRandomField(lr_multiplier=crf_lr_multiplier)
output = CRF(output)

# %%
model = Model(pretrained_bert.input, output)
model.summary()

model.compile(
    loss=CRF.sparse_loss,
    optimizer=Adam(learing_rate),
    metrics=[CRF.sparse_accuracy]
)

# %%
class NamedEntityRecognizer(ViterbiDecoder):
    """命名实体识别器
    """
    def recognize(self, text):
        tokens = tokenizer.tokenize(text)
        mapping = tokenizer.rematch(text, tokens)
        token_ids = tokenizer.tokens_to_ids(tokens)
        segment_ids = [0] * len(token_ids)
        token_ids, segment_ids = to_array([token_ids], [segment_ids])
        nodes = model.predict([token_ids, segment_ids])[0]
        labels = self.decode(nodes)
        entities, starting = [], False
        for i, label in enumerate(labels):
            if label > 0:
                if label % 2 == 1:
                    starting = True
                    entities.append([[i], id2label[(label - 1) // 2]])
                elif starting:
                    entities[-1][0].append(i)
                else:
                    starting = False
            else:
                starting = False

        return [(text[mapping[w[0]][0]:mapping[w[-1]][-1] + 1], l)
                for w, l in entities]


NER = NamedEntityRecognizer(trans=K.eval(CRF.trans), starts=[0], ends=[0])


def evaluate(data):
    """评测函数
    """
    X, Y, Z = 1e-10, 1e-10, 1e-10
    for d in tqdm(data):
        text = ''.join([i[0] for i in d])
        R = set(NER.recognize(text)) # 预测
        T = set([tuple(i) for i in d if i[1] != 'O']) #真实
        X += len(R & T) 
        Y += len(R) 
        Z += len(T)
    precision, recall =  X / Y, X / Z
    f1 = 2*precision*recall/(precision+recall)
    return f1, precision, recall


class Evaluator(keras.callbacks.Callback):
    def __init__(self,valid_data, best_model):
        self.best_val_f1 = 0
        self.valid_data = valid_data
        self.scheduler_patience = 1
        self.early_stop_patience = 3
        self.best_model = best_model
        self.pre_f1 = 0 # 保存上一轮的f1

    def on_epoch_end(self, epoch, logs=None):
        lr = K.get_value(model.optimizer.lr)
        trans = K.eval(CRF.trans)
        NER.trans = trans
        # print(NER.trans)
        f1, precision, recall = evaluate(self.valid_data)
        if f1 >= self.best_val_f1:
            # 取得新的最优f1, 更新最优f1, 保存模型
            self.best_val_f1 = f1
            model.save_weights(self.best_model)
        print(
            'valid:  f1: %.5f, precision: %.5f, recall: %.5f, best f1: %.5f, lr: %.6f\n' %
            (f1, precision, recall, self.best_val_f1, lr))
        if f1 >= self.pre_f1:
            # 若f1 优于上一轮，增大学习率、重置早停和patience计数器
            K.set_value(model.optimizer.lr, lr * 1.7)
            self.scheduler_patience = 1
            self.early_stop_patience = 3
        else:
            self.scheduler_patience -= 1
            self.early_stop_patience -= 1
            if self.early_stop_patience == 0:
                exit()
            # 若f1比上一轮的结果差，则降低学习率
            if self.scheduler_patience == 0:
                K.set_value(model.optimizer.lr, lr * 0.7)
                # 调整后，重置patience计数器
                self.scheduler_patience = 1

        # 更新pre_f1
        self.pre_f1 = f1

evaluator = Evaluator(valid_data, model_name)
train_generator = data_generator(train_data, batch_size)

model.fit_generator(
    train_generator.forfit(),
    steps_per_epoch=len(train_generator),
    epochs=epochs,
    callbacks=[evaluator]
)

# %% [markdown]
# ## 验证集

# %%
def _cut(sentence):
    """
    将一段文本切分成多个句子
    :param sentence:
    :return:
    """
    new_sentence = []
    sen = []
    for i in sentence:
        if i in ['。', '！', '？', '?'] and len(sen) != 0:
            sen.append(i)
            new_sentence.append("".join(sen))
            sen = []
            continue
        sen.append(i)

    if len(new_sentence) <= 1: # 一句话超过max_seq_length且没有句号的，用","分割，再长的不考虑了。
        new_sentence = []
        sen = []
        for i in sentence:
            if i.split(' ')[0] in ['，', ','] and len(sen) != 0:
                sen.append(i)
                new_sentence.append("".join(sen))
                sen = []
                continue
            sen.append(i)
    if len(sen) > 0:  # 若最后一句话无结尾标点，则加入这句话
        new_sentence.append("".join(sen))
    return new_sentence

def cut_test_set(text_list,len_treshold):
    cut_text_list = []
    cut_index_list = []
    for text in text_list:

        temp_cut_text_list = []
        text_agg = ''
        if len(text) < len_treshold:
            temp_cut_text_list.append(text)
        else:
            sentence_list = _cut(text)  # 一条数据被切分成多句话
            for sentence in sentence_list:
                if len(text_agg) + len(sentence) < len_treshold:
                    text_agg += sentence
                else:
                    temp_cut_text_list.append(text_agg)
                    text_agg = sentence
            temp_cut_text_list.append(text_agg)  # 加上最后一个句子

        cut_index_list.append(len(temp_cut_text_list))
        cut_text_list += temp_cut_text_list

    return cut_text_list, cut_index_list

# %%
class NamedEntityRecognizer(ViterbiDecoder):
    """命名实体识别器
    """
    def recognize(self, text):
        tokens = tokenizer.tokenize(text)
        mapping = tokenizer.rematch(text, tokens)
        token_ids = tokenizer.tokens_to_ids(tokens)
        segment_ids = [0] * len(token_ids)
        nodes = model.predict([[token_ids], [segment_ids]])[0]
        labels = self.decode(nodes)
        entities, starting = [], False
        
        for i, label in enumerate(labels):
            if label > 0:
                if label % 2 == 1:
                    starting = True
                    entities.append([[i], id2label[(label - 1) // 2]])
                elif starting:
                    entities[-1][0].append(i)
                else:
                    starting = False
            else:
                starting = False

        return [(text[mapping[w[0]][0]:mapping[w[-1]][-1] + 1], l)
                for w, l in entities]

# %%
model = Model(pretrained_bert.input, output)
model.load_weights(model_name)

# %%
NER = NamedEntityRecognizer(trans=K.eval(CRF.trans), starts=[0], ends=[0])

# %%
def test_predict(data, NER_):
    test_ner =[]
    
    for text in tqdm(data):
        cut_text_list, cut_index_list = cut_test_set([text],maxlen)
        posit = 0
        item_ner = []
        index =1
        for str_ in cut_text_list:
            aaaa  = NER_.recognize(str_)
            for tn in aaaa:
                ans = {}
                ans["label_type"] = tn[1]
                ans['overlap'] = "T" + str(index)
                
                ans["start_pos"] = text.find(tn[0],posit)
                ans["end_pos"] = ans["start_pos"] + len(tn[0])
                posit = ans["end_pos"]
                ans["res"] = tn[0]
                item_ner.append(ans)
                index +=1
        test_ner.append(item_ner)
    
    return test_ner

# %%
import glob 
import codecs
X, Y, Z = 1e-10, 1e-10, 1e-10
val_data_flist = glob.glob('./round1_train/val_data/*.txt')
data_dir = './round1_train/val_data/'
for file in val_data_flist:
    if file.find(".ann") == -1 and file.find(".txt") == -1:
        continue
    file_name = file.split('/')[-1].split('.')[0]
    r_ann_path = os.path.join(data_dir, "%s.ann" % file_name)
    r_txt_path = os.path.join(data_dir, "%s.txt" % file_name)

    R = []
    with codecs.open(r_txt_path, "r", encoding="utf-8") as f:
        line = f.readlines()
        aa = test_predict(line, NER)
        for line in aa[0]:
            lines = line['label_type']+ " "+str(line['start_pos'])+' ' +str(line['end_pos'])+ "\t" +line['res']
            R.append(lines)    
    T = []
    with codecs.open(r_ann_path, "r", encoding="utf-8") as f:
        for line in f:
            lines = line.strip('\n').split('\t')[1] + '\t' + line.strip('\n').split('\t')[2]
            T.append(lines)
    R = set(R)
    T = set(T)
    X += len(R & T) 
    Y += len(R) 
    Z += len(T)
precision, recall =  X / Y, X / Z
f1 = 2*precision*recall/(precision+recall)

# %%
f1,precision,recall

# %% [markdown]
# ## 测试集

# %%
class NamedEntityRecognizer(ViterbiDecoder):
    """命名实体识别器
    """
    def recognize(self, text):
        tokens = tokenizer.tokenize(text)
        mapping = tokenizer.rematch(text, tokens)
        token_ids = tokenizer.tokens_to_ids(tokens)
        segment_ids = [0] * len(token_ids)
        nodes = model.predict([[token_ids], [segment_ids]])[0]
        labels = self.decode(nodes)
        entities, starting = [], False
        
        for i, label in enumerate(labels):
            if label > 0:
                if label % 2 == 1:
                    starting = True
                    entities.append([[i], id2label[(label - 1) // 2]])
                elif starting:
                    entities[-1][0].append(i)
                else:
                    starting = False
            else:
                starting = False

        return [(text[mapping[w[0]][0]:mapping[w[-1]][-1] + 1], l)
                for w, l in entities]

# %%
NER = NamedEntityRecognizer(trans=K.eval(CRF.trans), starts=[0], ends=[0])

# %%
def test_predict(data, NER_):
    test_ner =[]
    
    for text in tqdm(data):
        cut_text_list, cut_index_list = cut_test_set([text],maxlen)
        posit = 0
        item_ner = []
        index =1
        for str_ in cut_text_list:
            ner_res  = NER_.recognize(str_)
            for tn in ner_res:
                ans = {}
                ans["label_type"] = tn[1]
                ans['overlap'] = "T" + str(index)
                
                ans["start_pos"] = text.find(tn[0],posit)
                ans["end_pos"] = ans["start_pos"] + len(tn[0])
                posit = ans["end_pos"]
                ans["res"] = tn[0]
                item_ner.append(ans)
                index +=1
        test_ner.append(item_ner)
    
    return test_ner

# %%
import os
import codecs

# %%
test_files = os.listdir("./round1_test/chusai_xuanshou/")

# %%
for file in test_files:
    with codecs.open("./round1_test/chusai_xuanshou/"+file, "r", encoding="utf-8") as f:
        line = f.readlines()
        aa = test_predict(line, NER)
    with codecs.open("./round1_test/submission_finetune_2layers/"+file.split('.')[0]+".ann", "w", encoding="utf-8") as ff:
        for line in aa[0]:
            lines = line['overlap'] + "\t" +line['label_type']+ " "+str(line['start_pos'])+' ' +str(line['end_pos'])+ "\t" +line['res']
            ff.write(lines+"\n")
        ff.close()
